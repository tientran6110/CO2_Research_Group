# %%
import pandas as pd

# %%
    
    # %%javascript
    IPython.OutputArea.prototype._should_scroll = function(lines) {
        return false;
    }

# %%
dataFinal = pd.read_csv('../sites/AUASMtempregression3row.csv')

# %%
    import numpy as np
    # %matplotlib inline
    import matplotlib.pyplot as plt
    import seaborn as sns
    import warnings
    warnings.filterwarnings("ignore")
    from sklearn.linear_model import LinearRegression
    from IPython.display import HTML
    import io
    import base64
    from scipy.spatial import distance
    from scipy import stats
    import os
    import nbformat as nbf


    if 'Time' in dataFinal.columns:
        dataFinal['Time'] = pd.to_datetime(dataFinal['Time'])
        dataFinal.set_index('Time', inplace=True)
        dataFinal['Year'] = dataFinal.index.year

    unique_years = dataFinal['Year'].unique()

    for year in unique_years:
        data_subset = dataFinal.loc[dataFinal['Year'] == year].copy()

        # Plotting
        fig, axs = plt.subplots(2, 1, figsize=(20, 12), sharex=True)
        axs[0].plot(data_subset.index, data_subset['Daily_NEE'], label='Daily_NEE')
        axs[0].plot(data_subset.index, data_subset['Daily_RECO_temp'], label='Daily_RECO_temp')
        axs[0].scatter(data_subset.index, data_subset['predicted_RECO'], color='red', label='predicted_RECO')
        axs[0].set_title(f'Daily_NEE & Daily_RECO_temp over Time for year {year}')
        axs[0].legend()

        axs[1].plot(data_subset.index, data_subset['Daily_EF'], label='Daily_EF')
        axs[1].bar(data_subset.index, data_subset['Daily_P'], color = 'red', label='Daily_P')
        axs[1].set_title(f'Daily_EF & Daily_P over Time for year {year}')
        axs[1].legend()

        plt.ylabel('Values')
        plt.xlabel('Time')

        plt.tight_layout()
        plt.show()

    # Press Cell - Current Output - Toggle Output to disable scorrling output of graph.

# %%
dataFinal.head()
# Out:
#             Unnamed: 0  Month  Year  predicted_RECO  Daily_NEE  \
# Time
# 2010-09-06           1    9.0  2010        1.333862   1.274113
# 2010-09-07           2    9.0  2010        1.627104   1.874769
# 2010-09-09           3    9.0  2010             NaN   0.791010
# 2010-09-11           4    9.0  2010        1.908496   1.823889
# 2010-09-12           5    9.0  2010        2.132539   1.939708
#
#             Daily_RECO_temp  Daily_RECO_flux  Daily_resi_temp  Daily_EF  \
# Time
# 2010-09-06         1.026161         1.279448         0.247952  0.387616
# 2010-09-07         1.306977         1.592810         0.567792  0.408107
# 2010-09-09         1.598797         1.590142        -0.807787  0.368495
# 2010-09-11         1.530859         1.608897         0.293030  0.502944
# 2010-09-12         1.723775         1.615547         0.215933  0.554273
#
#             Total_Randunc   Daily_P
# Time
# 2010-09-06       0.077012  0.000000
# 2010-09-07       0.094277  0.000000
# 2010-09-09       0.103069  0.023208
# 2010-09-11       0.116991  0.000000
# 2010-09-12       0.113434  0.050958

# %%
#2010
    
recoDf = dataFinal[dataFinal['predicted_RECO'].notnull()]
recoDf['RecoMinusNee'] = recoDf['predicted_RECO'] - recoDf['Daily_NEE']
recoDf['RecoMinusRecotemp'] = recoDf['predicted_RECO'] - recoDf['Daily_RECO_temp']
# recoDf.head(28)

# %%
#2010
layerOne = recoDf.copy()
layerOne['DailyP_Zero_F1'] = np.where((layerOne['Daily_P'] == 0) , 'Drop', 'Take')
# layerOne.head(28)

# %%
layerTwo = layerOne.copy()
layerTwo['Daily_NEE_Change'] = layerTwo['Daily_NEE'].diff(1)

# layerTwo.head(28)

# %%
layerThree = layerTwo.copy()
layerThree['Daily_RECO_temp_Change'] = layerThree['Daily_RECO_temp'].diff(1)

# layerThree.head(28)

# %%
import math
layerFour = layerThree.copy()
epsilon = math.pi/100

def compare_values(nee_change, reco_temp_change):
    if abs(nee_change - reco_temp_change) <= epsilon:
        return "Drop"
    else:
        return "Take"

layerFour['Slope_NEE_RECO_F2'] = layerFour.apply(lambda row: compare_values(row['Daily_NEE_Change'], row['Daily_RECO_temp_Change']), axis=1)
# layerFour.head(28)

# %%
layerFive = layerFour.copy()
layerFive['Daily_EF_Change'] = layerFive['Daily_EF'].diff(1)
layerFive['Daily_EF_Neg_F3'] = np.where((layerFive['Daily_EF_Change'] < 0) , 'Drop', 'Take')
# layerFive.head(28)

# %%
layerSix = layerFive.copy()

def check_drop(row):
    count = 0
    for col in ['DailyP_Zero_F1', 'Slope_NEE_RECO_F2', 'Daily_EF_Neg_F3']:
        if row[col] == 'Drop':
            count += 1
        if count >= 2:
            return 'Drop'
    return 'Take'

layerSix['FinalDrop'] = layerSix.apply(check_drop, axis=1)

# layerSix.head(28)

# %%
layerSeven = layerSix.copy()
# First, convert 'Time' from index to column
layerSeven.reset_index(level=0, inplace=True)

# Then create a new index starting from 1
layerSeven.index = layerSeven.index + 1

years = layerSeven['Year'].unique()  # List of unique years
layerSeven.rename(columns={'Unnamed: 0':'Original_Index'}, inplace=True)
# create an empty dictionary to store each dataframe
dfs = {}

# Using a for loop to create a dataframe for each unique year
for year in years:
    dfs["df_{}".format(year)] = layerSeven[layerSeven['Year'] == year]
    
# For example
df_2010 = dfs["df_2010"]
df_2010.head(28)

# the left most column (layerSeven index without name on top) is the red points index in a year (predicted_Reco)
# the Original_Index is the index of that point from the dataFinal (original data frame)
# Out:
#          Time  Original_Index  Month  Year  predicted_RECO  Daily_NEE  \
# 1  2010-09-06               1    9.0  2010        1.333862   1.274113
# 2  2010-09-07               2    9.0  2010        1.627104   1.874769
# 3  2010-09-11               4    9.0  2010        1.908496   1.823889
# 4  2010-09-12               5    9.0  2010        2.132539   1.939708
# 5  2010-09-19               8    9.0  2010        1.116793   0.981734
# 6  2010-09-23              12    9.0  2010        1.622471   1.798003
# 7  2010-09-30              16    9.5  2010        1.475459   1.654329
# 8  2010-10-08              19   10.0  2010        1.544765   1.700378
# 9  2010-10-12              22   10.0  2010        2.018211   1.757407
# 10 2010-10-15              23   10.0  2010        1.436222   1.197539
# 11 2010-10-18              26   10.0  2010        1.276937   1.152148
# 12 2010-10-21              29   10.0  2010        1.577172   1.447716
# 13 2010-10-24              31   10.0  2010        1.479163   1.436794
# 14 2010-10-30              33   10.0  2010        1.157145   1.272460
# 15 2010-11-02              36   11.0  2010        0.838863   0.718889
# 16 2010-11-12              42   11.0  2010        1.242122   1.487097
# 17 2010-11-15              43   11.0  2010        2.253339   2.157761
# 18 2010-11-16              44   11.0  2010        2.103532   2.235444
# 19 2010-11-26              54   11.0  2010        0.870288   0.967391
# 20 2010-11-27              55   11.0  2010        0.953894   0.947856
# 21 2010-12-10              59   12.0  2010        2.588363   2.225942
# 22 2010-12-16              61   12.0  2010        2.392105   2.219757
# 23 2010-12-19              63   12.0  2010        1.999036   2.398810
# 24 2010-12-20              64   12.0  2010        1.652796   1.640406
# 25 2010-12-22              66   12.0  2010        2.232832   2.087667
# 26 2010-12-27              71   12.0  2010        1.703449   1.583344
# 27 2010-12-30              74   12.0  2010        1.715809   1.891727
# 28 2010-12-31              75    6.0  2010        1.471752   1.323703
#
#     Daily_RECO_temp  Daily_RECO_flux  Daily_resi_temp  Daily_EF  ...  \
# 1          1.026161         1.279448         0.247952  0.387616  ...
# 2          1.306977         1.592810         0.567792  0.408107  ...
# 3          1.530859         1.608897         0.293030  0.502944  ...
# 4          1.723775         1.615547         0.215933  0.554273  ...
# 5          0.768725         0.901868         0.213009  0.454184  ...
# 6          1.336143         1.420243         0.461859  0.352372  ...
# 7          1.224184         1.284569         0.430145  0.294569  ...
# 8          1.203829         1.277020         0.496549  0.442422  ...
# 9          1.649372         1.667115         0.108036  0.488436  ...
# 10         1.087632         1.004547         0.109907  0.455045  ...
# 11         1.017667         1.012115         0.134481  0.307752  ...
# 12         1.343597         1.229100         0.104120  0.265380  ...
# 13         1.268406         1.422423         0.168388  0.227752  ...
# 14         0.807746         0.887370         0.464714  0.456378  ...
# 15         0.658425         0.725982         0.060464  0.177754  ...
# 16         0.985059         0.993042         0.502038  0.304113  ...
# 17         1.789156         1.585782         0.368605  0.645660  ...
# 18         1.779630         1.409980         0.455814  0.414333  ...
# 19         0.713304         0.702585         0.254087  0.139077  ...
# 20         0.758123         0.673603         0.189734  0.203040  ...
# 21         2.095370         1.735081         0.130573  0.693171  ...
# 22         2.095925         2.101225         0.123832  0.368619  ...
# 23         1.498444         1.800220         0.900366  0.705701  ...
# 24         1.237359         1.312502         0.403047  0.565278  ...
# 25         1.903882         1.782496         0.183784  0.422657  ...
# 26         1.475680         1.404393         0.107664  0.255806  ...
# 27         1.508651         1.706885         0.383076  0.221818  ...
# 28         1.219936         1.198558         0.103767  0.295459  ...
#
#      Daily_P  RecoMinusNee  RecoMinusRecotemp  DailyP_Zero_F1  \
# 1   0.000000      0.059749           0.307701            Drop
# 2   0.000000     -0.247665           0.320127            Drop
# 3   0.000000      0.084607           0.377637            Drop
# 4   0.050958      0.192831           0.408764            Take
# 5   0.000000      0.135059           0.348068            Drop
# 6   0.000000     -0.175531           0.286328            Drop
# 7   0.000000     -0.178869           0.251276            Drop
# 8   0.000000     -0.155614           0.340936            Drop
# 9   0.000000      0.260804           0.368839            Drop
# 10  0.000042      0.238683           0.348590            Take
# 11  0.000000      0.124789           0.259270            Drop
# 12  0.000000      0.129456           0.233575            Drop
# 13  0.000000      0.042369           0.210757            Drop
# 14  0.004083     -0.115315           0.349399            Take
# 15  0.000000      0.119974           0.180438            Drop
# 16  0.036687     -0.244975           0.257063            Take
# 17  0.002458      0.095578           0.464182            Take
# 18  0.018354     -0.131912           0.323902            Take
# 19  0.013062     -0.097103           0.156983            Take
# 20  0.009250      0.006038           0.195771            Take
# 21  0.118375      0.362421           0.492993            Take
# 22  0.000000      0.172348           0.296180            Drop
# 23  0.102292     -0.399774           0.500592            Take
# 24  0.000000      0.012390           0.415437            Drop
# 25  0.000000      0.145165           0.328950            Drop
# 26  0.000000      0.120105           0.227769            Drop
# 27  0.000000     -0.175917           0.207158            Drop
# 28  0.021469      0.148049           0.251816            Take
#
#    Daily_NEE_Change  Daily_RECO_temp_Change  Slope_NEE_RECO_F2  \
# 1               NaN                     NaN               Take
# 2          0.600656                0.280816               Take
# 3         -0.050881                0.223881               Take
# 4          0.115820                0.192917               Take
# 5         -0.957974               -0.955051               Drop
# 6          0.816269                0.567419               Take
# 7         -0.143674               -0.111960               Take
# 8          0.046050               -0.020355               Take
# 9          0.057029                0.445543               Take
# 10        -0.559868               -0.561740               Drop
# 11        -0.045391               -0.069965               Drop
# 12         0.295568                0.325930               Drop
# 13        -0.010922               -0.075191               Take
# 14        -0.164333               -0.460659               Take
# 15        -0.553571               -0.149321               Take
# 16         0.768207                0.326633               Take
# 17         0.670664                0.804098               Take
# 18         0.077683               -0.009526               Take
# 19        -1.268053               -1.066326               Take
# 20        -0.019535                0.044818               Take
# 21         1.278086                1.337247               Take
# 22        -0.006186                0.000555               Drop
# 23         0.179053               -0.597481               Take
# 24        -0.758404               -0.261085               Take
# 25         0.447261                0.666523               Take
# 26        -0.504322               -0.428202               Take
# 27         0.308382                0.032971               Take
# 28        -0.568024               -0.288714               Take
#
#    Daily_EF_Change  Daily_EF_Neg_F3 FinalDrop
# 1              NaN             Take      Take
# 2         0.020490             Take      Take
# 3         0.094837             Take      Take
# 4         0.051329             Take      Take
# 5        -0.100089             Drop      Drop
# 6        -0.101812             Drop      Drop
# 7        -0.057803             Drop      Drop
# 8         0.147853             Take      Take
# 9         0.046014             Take      Take
# 10       -0.033392             Drop      Drop
# 11       -0.147293             Drop      Drop
# 12       -0.042372             Drop      Drop
# 13       -0.037628             Drop      Drop
# 14        0.228626             Take      Take
# 15       -0.278624             Drop      Drop
# 16        0.126358             Take      Take
# 17        0.341548             Take      Take
# 18       -0.231328             Drop      Take
# 19       -0.275255             Drop      Take
# 20        0.063963             Take      Take
# 21        0.490131             Take      Take
# 22       -0.324552             Drop      Drop
# 23        0.337082             Take      Take
# 24       -0.140423             Drop      Drop
# 25       -0.142621             Drop      Drop
# 26       -0.166851             Drop      Drop
# 27       -0.033988             Drop      Drop
# 28        0.073641             Take      Take
#
# [28 rows x 21 columns]

# %%
#All points index matches, process to next step.
new_table = dataFinal[dataFinal['Unnamed: 0'].isin(layerSeven['Original_Index'])].copy()
new_table.head(28)
#This cell is only for checking. No useage
# Out:
#             Unnamed: 0  Month  Year  predicted_RECO  Daily_NEE  \
# Time
# 2010-09-06           1    9.0  2010        1.333862   1.274113
# 2010-09-07           2    9.0  2010        1.627104   1.874769
# 2010-09-11           4    9.0  2010        1.908496   1.823889
# 2010-09-12           5    9.0  2010        2.132539   1.939708
# 2010-09-19           8    9.0  2010        1.116793   0.981734
# 2010-09-23          12    9.0  2010        1.622471   1.798003
# 2010-09-30          16    9.5  2010        1.475459   1.654329
# 2010-10-08          19   10.0  2010        1.544765   1.700378
# 2010-10-12          22   10.0  2010        2.018211   1.757407
# 2010-10-15          23   10.0  2010        1.436222   1.197539
# 2010-10-18          26   10.0  2010        1.276937   1.152148
# 2010-10-21          29   10.0  2010        1.577172   1.447716
# 2010-10-24          31   10.0  2010        1.479163   1.436794
# 2010-10-30          33   10.0  2010        1.157145   1.272460
# 2010-11-02          36   11.0  2010        0.838863   0.718889
# 2010-11-12          42   11.0  2010        1.242122   1.487097
# 2010-11-15          43   11.0  2010        2.253339   2.157761
# 2010-11-16          44   11.0  2010        2.103532   2.235444
# 2010-11-26          54   11.0  2010        0.870288   0.967391
# 2010-11-27          55   11.0  2010        0.953894   0.947856
# 2010-12-10          59   12.0  2010        2.588363   2.225942
# 2010-12-16          61   12.0  2010        2.392105   2.219757
# 2010-12-19          63   12.0  2010        1.999036   2.398810
# 2010-12-20          64   12.0  2010        1.652796   1.640406
# 2010-12-22          66   12.0  2010        2.232832   2.087667
# 2010-12-27          71   12.0  2010        1.703449   1.583344
# 2010-12-30          74   12.0  2010        1.715809   1.891727
# 2010-12-31          75    6.0  2010        1.471752   1.323703
#
#             Daily_RECO_temp  Daily_RECO_flux  Daily_resi_temp  Daily_EF  \
# Time
# 2010-09-06         1.026161         1.279448         0.247952  0.387616
# 2010-09-07         1.306977         1.592810         0.567792  0.408107
# 2010-09-11         1.530859         1.608897         0.293030  0.502944
# 2010-09-12         1.723775         1.615547         0.215933  0.554273
# 2010-09-19         0.768725         0.901868         0.213009  0.454184
# 2010-09-23         1.336143         1.420243         0.461859  0.352372
# 2010-09-30         1.224184         1.284569         0.430145  0.294569
# 2010-10-08         1.203829         1.277020         0.496549  0.442422
# 2010-10-12         1.649372         1.667115         0.108036  0.488436
# 2010-10-15         1.087632         1.004547         0.109907  0.455045
# 2010-10-18         1.017667         1.012115         0.134481  0.307752
# 2010-10-21         1.343597         1.229100         0.104120  0.265380
# 2010-10-24         1.268406         1.422423         0.168388  0.227752
# 2010-10-30         0.807746         0.887370         0.464714  0.456378
# 2010-11-02         0.658425         0.725982         0.060464  0.177754
# 2010-11-12         0.985059         0.993042         0.502038  0.304113
# 2010-11-15         1.789156         1.585782         0.368605  0.645660
# 2010-11-16         1.779630         1.409980         0.455814  0.414333
# 2010-11-26         0.713304         0.702585         0.254087  0.139077
# 2010-11-27         0.758123         0.673603         0.189734  0.203040
# 2010-12-10         2.095370         1.735081         0.130573  0.693171
# 2010-12-16         2.095925         2.101225         0.123832  0.368619
# 2010-12-19         1.498444         1.800220         0.900366  0.705701
# 2010-12-20         1.237359         1.312502         0.403047  0.565278
# 2010-12-22         1.903882         1.782496         0.183784  0.422657
# 2010-12-27         1.475680         1.404393         0.107664  0.255806
# 2010-12-30         1.508651         1.706885         0.383076  0.221818
# 2010-12-31         1.219936         1.198558         0.103767  0.295459
#
#             Total_Randunc   Daily_P
# Time
# 2010-09-06       0.077012  0.000000
# 2010-09-07       0.094277  0.000000
# 2010-09-11       0.116991  0.000000
# 2010-09-12       0.113434  0.050958
# 2010-09-19       0.070832  0.000000
# 2010-09-23       0.087455  0.000000
# 2010-09-30       0.085562  0.000000
# 2010-10-08       0.084257  0.000000
# 2010-10-12       0.083174  0.000000
# 2010-10-15       0.075220  0.000042
# 2010-10-18       0.077077  0.000000
# 2010-10-21       0.074674  0.000000
# 2010-10-24       0.080800  0.000000
# 2010-10-30       0.066319  0.004083
# 2010-11-02       0.059297  0.000000
# 2010-11-12       0.058653  0.036687
# 2010-11-15       0.060404  0.002458
# 2010-11-16       0.062365  0.018354
# 2010-11-26       0.054763  0.013062
# 2010-11-27       0.058365  0.009250
# 2010-12-10       0.070894  0.118375
# 2010-12-16       0.120446  0.000000
# 2010-12-19       0.096712  0.102292
# 2010-12-20       0.097167  0.000000
# 2010-12-22       0.103049  0.000000
# 2010-12-27       0.099958  0.000000
# 2010-12-30       0.107584  0.000000
# 2010-12-31       0.095631  0.021469

# %%
# merge dataFinal and layerSevens on 'Unnamed: 0' column
merged_df = pd.merge(dataFinal, layerSeven, how='inner', left_on='Unnamed: 0', right_on='Original_Index')

# filter rows where FinalDrop is Drop
filtered_df = merged_df.query('FinalDrop != "Drop"')
filtered_df = filtered_df.rename(columns = {'Unnamed: 0':'Index_Origin'})
filtered_df.index = np.arange(1, len(filtered_df) + 1)
filtered_df.head(12)
# Out:
#        Time_x  Index_Origin  Month_x  Year_x  predicted_RECO_x  Daily_NEE_x  \
# 1  2010-09-06             1      9.0    2010          1.333862     1.274113
# 2  2010-09-07             2      9.0    2010          1.627104     1.874769
# 3  2010-09-11             4      9.0    2010          1.908496     1.823889
# 4  2010-09-12             5      9.0    2010          2.132539     1.939708
# 5  2010-10-08            19     10.0    2010          1.544765     1.700378
# 6  2010-10-12            22     10.0    2010          2.018211     1.757407
# 7  2010-10-30            33     10.0    2010          1.157145     1.272460
# 8  2010-11-12            42     11.0    2010          1.242122     1.487097
# 9  2010-11-15            43     11.0    2010          2.253339     2.157761
# 10 2010-11-16            44     11.0    2010          2.103532     2.235444
# 11 2010-11-26            54     11.0    2010          0.870288     0.967391
# 12 2010-11-27            55     11.0    2010          0.953894     0.947856
#
#     Daily_RECO_temp_x  Daily_RECO_flux_x  Daily_resi_temp_x  Daily_EF_x  ...  \
# 1            1.026161           1.279448           0.247952    0.387616  ...
# 2            1.306977           1.592810           0.567792    0.408107  ...
# 3            1.530859           1.608897           0.293030    0.502944  ...
# 4            1.723775           1.615547           0.215933    0.554273  ...
# 5            1.203829           1.277020           0.496549    0.442422  ...
# 6            1.649372           1.667115           0.108036    0.488436  ...
# 7            0.807746           0.887370           0.464714    0.456378  ...
# 8            0.985059           0.993042           0.502038    0.304113  ...
# 9            1.789156           1.585782           0.368605    0.645660  ...
# 10           1.779630           1.409980           0.455814    0.414333  ...
# 11           0.713304           0.702585           0.254087    0.139077  ...
# 12           0.758123           0.673603           0.189734    0.203040  ...
#
#     Daily_P_y  RecoMinusNee RecoMinusRecotemp  DailyP_Zero_F1  \
# 1    0.000000      0.059749          0.307701            Drop
# 2    0.000000     -0.247665          0.320127            Drop
# 3    0.000000      0.084607          0.377637            Drop
# 4    0.050958      0.192831          0.408764            Take
# 5    0.000000     -0.155614          0.340936            Drop
# 6    0.000000      0.260804          0.368839            Drop
# 7    0.004083     -0.115315          0.349399            Take
# 8    0.036687     -0.244975          0.257063            Take
# 9    0.002458      0.095578          0.464182            Take
# 10   0.018354     -0.131912          0.323902            Take
# 11   0.013062     -0.097103          0.156983            Take
# 12   0.009250      0.006038          0.195771            Take
#
#     Daily_NEE_Change  Daily_RECO_temp_Change  Slope_NEE_RECO_F2  \
# 1                NaN                     NaN               Take
# 2           0.600656                0.280816               Take
# 3          -0.050881                0.223881               Take
# 4           0.115820                0.192917               Take
# 5           0.046050               -0.020355               Take
# 6           0.057029                0.445543               Take
# 7          -0.164333               -0.460659               Take
# 8           0.768207                0.326633               Take
# 9           0.670664                0.804098               Take
# 10          0.077683               -0.009526               Take
# 11         -1.268053               -1.066326               Take
# 12         -0.019535                0.044818               Take
#
#     Daily_EF_Change  Daily_EF_Neg_F3  FinalDrop
# 1               NaN             Take       Take
# 2          0.020490             Take       Take
# 3          0.094837             Take       Take
# 4          0.051329             Take       Take
# 5          0.147853             Take       Take
# 6          0.046014             Take       Take
# 7          0.228626             Take       Take
# 8          0.126358             Take       Take
# 9          0.341548             Take       Take
# 10        -0.231328             Drop       Take
# 11        -0.275255             Drop       Take
# 12         0.063963             Take       Take
#
# [12 rows x 33 columns]

# %%
    if 'Time_x' in filtered_df.columns:
        filtered_df['Time_x'] = pd.to_datetime(filtered_df['Time_x'])
        filtered_df.set_index('Time_x', inplace=True)
        filtered_df['Year_x'] = filtered_df.index.year

    unique_years_final = filtered_df['Year_x'].unique()

    for year in unique_years_final:
        data_subset_final = filtered_df.loc[filtered_df['Year_x'] == year].copy()

        # Plotting
        fig, axs = plt.subplots(2, 1, figsize=(16, 8), sharex=True)
        axs[0].plot(data_subset_final.index, data_subset_final['Daily_NEE_x'], label='Daily_NEE')
        axs[0].plot(data_subset_final.index, data_subset_final['Daily_RECO_temp_x'], label='Daily_RECO_temp')
        axs[0].scatter(data_subset_final.index, data_subset_final['predicted_RECO_x'], color='red', label='predicted_RECO')
        axs[0].set_title(f'Daily_NEE & Daily_RECO_temp over Time for year {year}')
        axs[0].legend()

        axs[1].plot(data_subset_final.index, data_subset_final['Daily_EF_x'], label='Daily_EF')
        axs[1].bar(data_subset_final.index, data_subset_final['Daily_P_x'], color = 'red', label='Daily_P')
        axs[1].set_title(f'Daily_EF & Daily_P over Time for year {year}')
        axs[1].legend()

        plt.ylabel('Values')
        plt.xlabel('Time')

        plt.tight_layout()
        plt.show()

# %%
#number of dropped points in 4 years
drop_rows = layerSeven[layerSeven['FinalDrop'] == 'Drop']
drop_rows.shape[0]
# Out:
# 59

# %%
#origin Data Frame rows
dataFinal.shape[0]
# Out:
# 927
